# %%
# Dependencies
import json
import tweepy 

# Twitter API Keys
consumer_key = "jCiriQ41RK64ab9oXgHabNwPp"
consumer_secret = "TvS2Nv5U1sBHEGRXVopVlWZ2GYmLCuQQy8p86usTpPoyRkF4vf"
access_token = "974457981751341056-s97fzzjtyhoerni3DK2M25H7JRiP9VZ"
access_token_secret = "rlRiUCYUlSkQKqatkQTl9zO2ec0k2CSAi959pDNJHWd0s"

# Setup Tweepy API Authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# Get all tweets from home feed
public_tweets = api.home_timeline()

# Loop through all tweets
for tweet in public_tweets:
    # Utilize JSON dumps to generate a pretty-printed json
    print(json.dumps(tweet, sort_keys=True, indent=4, separators=(',', ': ')))
# Out:
# {
#     "contributors": null,
#     "coordinates": null,
#     "created_at": "Fri Mar 16 01:45:05 +0000 2018",
#     "entities": {
#         "hashtags": [],
#         "symbols": [],
#         "urls": [
#             {
#                 "display_url": "on.wsj.com/2plaM6S",
#                 "expanded_url": "http://on.wsj.com/2plaM6S",
#                 "indices": [
#                     78,
#                     101
#                 ],
#                 "url": "https://t.co/oUks1LwycV"
#             }
#         ],
#         "user_mentions": []
#     },
#     "favorite_count": 65,
#     "favorited": false,
#     "geo": null,
#     "id": 974461520187920384,
#     "id_str": "974461520187920384",
#     "in_reply_to_screen_name": null,
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "is_quote_status": false,
#     "lang": "en",
#     "place": null,
# ...
